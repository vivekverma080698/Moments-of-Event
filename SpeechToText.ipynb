# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install --upgrade google-cloud-speech
#!pip install SpeechRecognition
#!sudo apt-get install -qq python python-dev python-pip build-essential swig libpulse-dev
#!pip install pocketsphinx
# !pip install ibm_watson

# %%
import speech_recognition as sr
import sys
from moviepy.editor import *
import os

# %%
basedir = '/content/drive/My\ Drive/MultimediaProject/'

# %%
cd /content/drive/My\ Drive/MultimediaProject/
# Out:
# /content/drive/My Drive/MultimediaProject

# %%
filename = 'Dataset/sample4.mp4'
video = VideoFileClip(filename)
audio = video.audio
print(audio)
audio.write_audiofile(filename[:-3]+'wav')
# Out:
# ...
# [MoviePy] Writing audio in Dataset/sample4.wav
# 100%|██████████| 6578/6578 [00:04<00:00, 1503.30it/s]
# [MoviePy] Done.

# %%
r = sr.Recognizer()
with sr.AudioFile('Dataset/sample2.wav') as source:
    audio = r.record(source)

# %%
# print( r.recognize_sphinx(audio))
# GOOGLE_CLOUD_SPEECH_CREDENTIALS = r"""{
#   "type": "service_account",
#   "project_id": "speechtotext-257717",
#   "private_key_id": "50d971152216afc6f7fe69a3a50010af7c3a545c",
#   "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
#   "client_email": "sppechtotext@speechtotext-257717.iam.gserviceaccount.com",
#   "client_id": "117352779445114316089",
#   "auth_uri": "https://accounts.google.com/o/oauth2/auth",
#   "token_uri": "https://oauth2.googleapis.com/token",
#   "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
#   "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/sppechtotext%40speechtotext-257717.iam.gserviceaccount.com"
# }
# """
try:
    print("Google Speech Recognition thinks you said " + r.recognize_google(audio,key="AIzaSyCQ39batAwkfnWU2hv9zl0D5JXYox9z_dM"))
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
# print("Google Cloud Speech thinks you said " + r.recognize_google_cloud(audio, credentials_json=GOOGLE_CLOUD_SPEECH_CREDENTIALS))
# Out:
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 32] Broken pipe

# %%
import json
import threading
from os.path import join, dirname
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.websocket import RecognizeCallback, AudioSource

authenticator = IAMAuthenticator('Sx7Vpt5Ae1mrdwH3zZDAkncS1RehVeubcgWO1L3raZp_')
service = SpeechToTextV1(authenticator=authenticator)
service.set_service_url('https://gateway-lon.watsonplatform.net/speech-to-text/api')

with open('Dataset/sample3.wav','rb') as audio_file:
    print(json.dumps(
        service.recognize( 
            audio=audio_file,
            content_type='audio/wav',
            timestamps=True,
            word_confidence=True).get_result(),
        indent=2))
# Out:
# {
#   "results": [
#     {
#       "alternatives": [
#         {
#           "timestamps": [
#             [
#               "Dr",
#               1.41,
#               1.7
#             ],
#             [
#               "green",
#               1.7,
#               2.29
#             ]
#           ],
#           "confidence": 0.97,
#           "transcript": "Dr green ",
#           "word_confidence": [
#             [
#               "Dr",
#               1.0
#             ],
#             [
#               "green",
#               0.95
#             ]
#           ]
#         }
#       ],
#       "final": true
#     },
#     {
#       "alternatives": [
#         {
#           "timestamps": [
#             [
#               "it's",
#               3.85,
#               4.04
#             ],
#             [
#               "Rachel's",
#               4.04,
#               4.55
#             ]
#           ],
#           "confidence": 0.39,
#           "transcript": "it's Rachel's ",
# ...

# %%
with open('Dataset/sample1.wav','rb') as audio_file:
    print(json.dumps(
        service.recognize( 
            audio=audio_file,
            content_type='audio/wav',
            timestamps=True,
            word_confidence=True).get_result(),
        indent=2))
# Out:
# {
#   "results": [
#     {
#       "alternatives": [
#         {
#           "timestamps": [
#             [
#               "what",
#               158.79,
#               159.03
#             ],
#             [
#               "he",
#               159.03,
#               159.23
#             ],
#             [
#               "doing",
#               159.23,
#               159.56
#             ],
#             [
#               "bad",
#               159.56,
#               159.97
#             ]
#           ],
#           "confidence": 0.5,
#           "transcript": "what he doing bad ",
#           "word_confidence": [
#             [
#               "what",
#               0.06
#             ],
#             [
#               "he",
#               0.15
#             ],
#             [
#               "doing",
#               0.67
#             ],
#             [
#               "bad",
#               0.8
#             ]
#           ]
#         }
#       ],
# ...

# %%
with open('Dataset/sample4.wav','rb') as audio_file:
    print(json.dumps(
        service.recognize( 
            audio=audio_file,
            content_type='audio/wav',
            timestamps=True,
            word_confidence=True).get_result(),
        indent=2))
# Out:
# {
#   "results": [
#     {
#       "alternatives": [
#         {
#           "timestamps": [
#             [
#               "Happy",
#               2.31,
#               2.62
#             ],
#             [
#               "Birthday",
#               2.62,
#               3.02
#             ],
#             [
#               "grandma",
#               3.02,
#               3.51
#             ]
#           ],
#           "confidence": 0.91,
#           "transcript": "Happy Birthday grandma ",
#           "word_confidence": [
#             [
#               "Happy",
#               0.96
#             ],
#             [
#               "Birthday",
#               0.96
#             ],
#             [
#               "grandma",
#               0.85
#             ]
#           ]
#         }
#       ],
#       "final": true
#     },
#     {
#       "alternatives": [
#         {
#           "timestamps": [
#             [
#               "it's",
#               6.97,
# ...
